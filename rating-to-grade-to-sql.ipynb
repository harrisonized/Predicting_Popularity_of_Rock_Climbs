# %%
import pandas as pd
import pandas.io.sql as pd_sql
from sqlalchemy import create_engine

# sqlalchemy connection arguments
connection_str = f'postgres://postgres:{None}@localhost:5432/mountain_project'
engine = create_engine(connection_str)

# %%
rating_to_grade_dict = {'V-easy': -1, 'V-easy PG13': -1, '5.9 V-easy': -1, 'V-easy R': -0.75,
                   'V0-': -0.25, '5.9 V0-': -0.25, 'V0- PG13': -0.25, 'V0- R': -0.25,
                   '5.8+ V0': 0, '5.9 V0': 0, 'V0': 0, 'V0 PG13': 0,
                   '5.10a V0 R': 0.25, 'V0 R': 0.25, 'V0 X': 0.25, '5.8+ V0 X': 0.25, 'V0+': 0.25, 'V0+ PG13': 0.25,
                   'V0+ R': 0.5, 'V0-1': 0.5, '5.10- V0-1': 0.5,
                   'V1-': 0.75, 'V1': 1, 'V1 PG13': 1, '5.9 V1': 1,
                   'V1 R': 1.25, 'V1 X':1.25, 'V1+': 1.25, 'V1+ PG13': 1.25, 'V1-2': 1.5, 
                   'V2-': 1.75, '5.10+ V2': 2, 'V2': 2, 'V2 PG13': 2, '5.11b V2': 2,
                   'V2 R': 2.25, 'V2+': 2.25, 'V2-3': 2.5, '5.10- V2-3': 2.5, 'V2+ X': 2.5, 
                   'V3-': 2.75, 'V3- R': 3, 'V3': 3, 'V3 PG13': 3,
                   'V3 R': 3.25, '5.11c V3 R': 3.25, 'V3+': 3.25, 'V3+ R':3.5, 'V3-4': 3.5,
                   'V4-': 3.75, 'V4': 4, 'V4 PG13': 4,
                   'V4 R': 4.25, 'V4 X': 4.25, 'V4+': 4.25, 'V4+ PG13': 4.25, 'V4-5': 4.5,
                   'V5-': 4.75, 'V5': 5, 'V5 PG13': 5, '5.12c V5 X': 5,
                   'V5 R': 5.25, 'V5+': 5.25, 'V5+ X': 5.5, 'V5-6': 5.5,
                   'V6-': 5.75, 'V6- PG13': 5.75, 'V6- R': 6, 'V6': 6, 'V6 PG13': 6,
                   'V6 R': 6.25, 'V6+': 6.25,  'V6-7': 6.5, 'V6-7 PG13': 6.5, 
                   'V7-': 6.75, 'V7': 7, 'V7 PG13': 7,
                   'V7 R': 7.25, 'V7+':7.25, 'V7-8': 7.5,   
                   'V7-8 R': 7.75, 'V8-': 7.75, 'V8': 8, 'V8 PG13': 8,
                   'V8 R':8.25, 'V8 X': 8.25, 'V8+': 8.25, 'V8-9': 8.5, 
                   'V9-': 8.75, 'V9': 9, 'V9 PG13': 9,
                   'V9 R': 9.25, 'V9+': 9.25, 'V9+ PG13': 9.25, 'V9 X': 9.25, 'V9-10':9.5, 'V9-10 PG13': 9.5, 
                   'V10-': 9.75, 'V10': 10, 'V10 PG13': 10,
                   'V10 R': 10.25, 'V10 X': 10.25, 'V10+': 10.25,  'V10-11': 10.5, 'V10-11 PG13': 10.5,
                   'V11-': 10.75, 'V11': 11,
                   'V11 R': 11.25, 'V11 X': 11.25, 'V11-12': 11.5,
                   'V12-': 11.75, 'V12': 12, 'V12 PG13': 12,
                   'V12+': 12.25, 'V12-13 R': 12.5,
                   'V13': 13,  'V13 PG13': 13, 'V13 R': 13.25, 'V13-14 PG13': 13.5,
                   'V14': 14}

# %%
rating_to_grade_df = pd.DataFrame(list(rating_to_grade_dict.items()), columns=['rating', 'grade'])
rating_to_grade_df.to_sql('rating_to_grade', engine, index=False)

# %%
rating_to_grade_df = pd_sql.read_sql("SELECT * FROM rating_to_grade", connection)
rating_to_grade_df
# Out:
#           rating  grade
# 0         V-easy  -1.00
# 1    V-easy PG13  -1.00
# 2     5.9 V-easy  -1.00
# 3       V-easy R  -0.75
# 4            V0-  -0.25
# 5        5.9 V0-  -0.25
# 6       V0- PG13  -0.25
# 7          V0- R  -0.25
# 8        5.8+ V0   0.00
# 9         5.9 V0   0.00
# 10            V0   0.00
# 11       V0 PG13   0.00
# 12    5.10a V0 R   0.25
# 13          V0 R   0.25
# 14          V0 X   0.25
# 15     5.8+ V0 X   0.25
# 16           V0+   0.25
# 17      V0+ PG13   0.25
# 18         V0+ R   0.50
# 19          V0-1   0.50
# 20    5.10- V0-1   0.50
# 21           V1-   0.75
# 22            V1   1.00
# 23       V1 PG13   1.00
# 24        5.9 V1   1.00
# 25          V1 R   1.25
# 26          V1 X   1.25
# 27           V1+   1.25
# 28      V1+ PG13   1.25
# 29          V1-2   1.50
# ..           ...    ...
# 90       V9 PG13   9.00
# 91          V9 R   9.25
# 92           V9+   9.25
# 93      V9+ PG13   9.25
# 94          V9 X   9.25
# 95         V9-10   9.50
# 96    V9-10 PG13   9.50
# 97          V10-   9.75
# 98           V10  10.00
# 99      V10 PG13  10.00
# 100        V10 R  10.25
# 101        V10 X  10.25
# 102         V10+  10.25
# 103       V10-11  10.50
# 104  V10-11 PG13  10.50
# 105         V11-  10.75
# 106          V11  11.00
# 107        V11 R  11.25
# 108        V11 X  11.25
# 109       V11-12  11.50
# 110         V12-  11.75
# 111          V12  12.00
# 112     V12 PG13  12.00
# 113         V12+  12.25
# 114     V12-13 R  12.50
# 115          V13  13.00
# 116     V13 PG13  13.00
# 117        V13 R  13.25
# 118  V13-14 PG13  13.50
# 119          V14  14.00
#
# [120 rows x 2 columns]
