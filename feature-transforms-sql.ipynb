# %%
import pandas as pd
import math

import pandas.io.sql as pd_sql
import psycopg2 as pg
from sqlalchemy import create_engine

# psychopg connection parameters
params = {'user': 'postgres', 'host': 'localhost', 'port': 5432, 'password': None}
connection = pg.connect(**params, dbname='mountain_project') # Connect
cursor = connection.cursor()

# sqlalchemy connection arguments
connection_str = f'postgres://postgres:{None}@localhost:5432/mountain_project'
engine = create_engine(connection_str)

# %%
buttermilks_df = pd_sql.read_sql("SELECT * FROM buttermilks", connection)
buttermilks_df.
# Out:
#      id_                        route  \
# 0     14                Unknown V0/V1
# 1     15                    Problem A
# 2     16                    Problem C
# 3     17                Xenolith Slab
# 4     18                    Knob Slab
# 5     19               Backside Crack
# 6     20              Burned and Bare
# 7     21                Original Line
# 8     22                 Vic's Demise
# 9     23            Essential Peabody
# 10    24     Advanced Rockcraft Arete
# 11    25                    Problem A
# 12    26              Birthday Mantel
# 13    27                    Problem B
# 14    28     Robinson's Rubber Tester
# 15    29                   Unnamed  3
# 16    30                    Problem A
# 17    31                  Hager Arete
# 18    32                Unnamed Arete
# 19    33                       Unnmed
# 20    34                    Hero Roof
# 21    35                    Problem D
# 22    36                    Problem G
# 23    37                    Problem H
# 24    38                    Tall Edgy
# 25    39           Five and Dime Left
# 26    40          Five and Dime Right
# 27    41              Northwest Flake
# 28    42                Howard Carter
# 29    43                Egypt (crack)
# ..   ...                          ...
# 367  376                  Thunderbird
# 368  377                     Ambrosia
# 369  378                   La Belette
# 370  388           Rastaman Vibration
# 371  389               Form Destroyer
# 372  390              A Maze of Death
# 373  391                    Evilution
# 374  392                      Spectre
# 375  393                    Direction
# 376  394                 Buttermilker
# 377  395     The Beautiful and Damned
# 378  396             The Swarm Direct
# 379  397                    The Swarm
# 380  238                  Eric's Dyno
# 381    9                    Downclimb
# 382   10                   Unnamed  1
# 383   11                   Unnamed  2
# 384   12                    Problem B
# 385   13                Hip Hop Hager
# 386   58                    Sketchpad
# 387  166                      The Pit
# 388  379            Les Trois Maunets
# 389  380                 Butterfinger
# 390  381                   Sex Kitten
# 391  382  Haroun & the Sea of Stories
# 392  383                  The Mandala
# 393  384             A Scanner Darkly
# 394  385      Michael Caine Sit Start
# 395  386                      Mystery
# 396  387                      Baburre
#
#                                               location  \
# 0    The Loaf > Buttermilks Main > Buttermilk Count...
# 1    Fit Homeless Boulder > Buttermilks Main > Butt...
# 2    Fit Homeless Boulder > Buttermilks Main > Butt...
# 3    Agent Orange Boulder > Zeppelin Area > Dale's ...
# 4    Warmup Boulders > Bardini Boulders > Buttermil...
# 5    Get Carter Boulder > Buttermilk Country > Bish...
# 6    Get Carter Boulder > Buttermilk Country > Bish...
# 7    Lidija / Pollen Grain Boulder > Pollen Grains ...
# 8    Mead Boulder > Pollen Grains / Lidija Boulders...
# 9    Grandma Peabody Boulder > Peabody Boulders > B...
# 10   Grandpa Peabody Boulder > Peabody Boulders > B...
# 11   Birthday Boulders > Buttermilks Main > Butterm...
# 388  https://www.mountainproject.com/route/11414583...        2.0          -1
# 389  https://www.mountainproject.com/route/11568192...        3.0          -1
# 390  https://www.mountainproject.com/route/11539419...        4.0          -1
# 391  https://www.mountainproject.com/route/10607095...        4.0          -1
# 392  https://www.mountainproject.com/route/10590818...        3.3          -1
# 393  https://www.mountainproject.com/route/11168400...        3.3          -1
# 394  https://www.mountainproject.com/route/11389117...        2.0          -1
# 395  https://www.mountainproject.com/route/10956386...        4.0          -1
# 396  https://www.mountainproject.com/route/11410636...        2.0          -1
#
#           route_type       rating  pitches  length_  area_latitude  \
# 0            Boulder          V0-        1     12.0       37.33022
# 1            Boulder          V0-        1      NaN       37.32895
# 2            Boulder          V0-        1      NaN       37.32895
# 3            Boulder          V0-        1     10.0       37.31821
# 4            Boulder          V0-        1      NaN       37.31829
# 5            Boulder           V0        1     20.0       37.33880
# 6            Boulder           V0        1     15.0       37.33880
# 7            Boulder           V0        1     35.0       37.33770
# 8            Boulder         V0 X        1     35.0       37.33780
# 9            Boulder           V0        1     40.0       37.32837
# 10           Boulder    5.8+ V0 X        1     50.0       37.32817
# 11           Boulder           V0        1     12.0       37.33004
# 12           Boulder           V0        1     12.0       37.33004
# 13           Boulder           V0        1     12.0       37.33004
# 14           Boulder           V0        1      NaN       37.32867
# 15           Boulder           V0        1     18.0       37.32859
# 16           Boulder           V0        1     15.0       37.32873
# 17           Boulder           V0        1     15.0       37.33014
# 18           Boulder           V0        1     20.0       37.33014
# 19           Boulder           V0        1     15.0       37.33014
# 20           Boulder           V0        1     14.0       37.33000
# 21           Boulder           V0        1      NaN       37.32964
# 22           Boulder           V0        1      NaN       37.32964
# 23           Boulder           V0        1      NaN       37.32964
# 24           Boulder           V0        1     24.0       37.32944
# 25           Boulder           V0        1      NaN       37.33057
# 26           Boulder           V0        1      NaN       37.33057
# 27           Boulder           V0        1     12.0       37.32900
# 28           Boulder           V0        1      NaN       37.32900
# 29           Boulder           V0        1      NaN       37.32900
# ..               ...          ...      ...      ...            ...
# 367          Boulder          V11        1     15.0       37.32837
# 368          Boulder        V11 X        1     55.0       37.32817
# 369          Boulder          V11        1     12.0       37.32817
# 370          Boulder          V12        1     50.0       37.32817
# 371          Boulder          V12        1     10.0       37.33673
# 372          Boulder          V12        1     14.0       37.31926
# 373          Boulder     V12-13 R        1     55.0       37.32817
# 374          Boulder          V13        1      NaN       37.33810
# 375          Boulder        V13 R        1     50.0       37.32837
# 376          Boulder          V13        1     20.0       37.32863
# 377          Boulder     V13 PG13        1     35.0       37.31797
# 378          Boulder  V13-14 PG13        1     25.0       37.33726
# 379          Boulder          V14        1     20.0       37.33726
# 380          Boulder           V5        1      NaN       37.32013
# 381          Boulder       V-easy        1      NaN       37.31829
# 382          Boulder          V0-        1     18.0       37.32859
# 383          Boulder          V0-        1     18.0       37.32859
# 384          Boulder          V0-        1     12.0       37.32873
# 385          Boulder          V0-        1     16.0       37.33014
# 386          Boulder        V0+ R        1     30.0       37.29910
# 387  Boulder, Alpine      V3 PG13        1      NaN       37.28678
# 388          Boulder          V11        1      NaN       37.32888
# 389          Boulder          V11        1     30.0       37.32909
# 390          Boulder          V11        1     25.0       37.33501
# 391          Boulder       V11-12        1     20.0       37.33057
# 392          Boulder         V12-        1     20.0       37.32909
# 393          Boulder          V12        1      NaN       37.33880
# 394          Boulder          V12        1     15.0       37.33880
# 395          Boulder          V12        1     30.0       37.32837
# 396          Boulder          V12        1     25.0       37.32837
#
#      area_longitude     url_id  grade
# 0        -118.57882  106442771  -0.25
# 1        -118.57595  106060959  -0.25
# 2        -118.57595  106060972  -0.25
# 3        -118.57395  116715297  -0.25
# 4        -118.58630  114054760  -0.25
# 5        -118.57760  108010816   0.00
# 6        -118.57760  108880968   0.00
# 7        -118.57010  108054564   0.00
# 8        -118.57200  111450402   0.25
# 9        -118.57479  106395083   0.00
# 10       -118.57477  109526745   0.25
# 11       -118.57901  106277503   0.00
# 12       -118.57901  106277514   0.00
# 13       -118.57901  106277521   0.00
# 14       -118.57681  105936126   0.00
# 15       -118.57516  107032785   0.00
# 16       -118.57534  106322566   0.00
# 17       -118.57777  105936748   0.00
# 18       -118.57777  105936754   0.00
# 19       -118.57777  111731481   0.00
# 20       -118.57820  106094805   0.00
# 21       -118.57869  105936776   0.00
# 22       -118.57869  105936802   0.00
# 23       -118.57869  106060929   0.00
# 24       -118.57548  115681932   0.00
# 25       -118.57834  107204109   0.00
# 26       -118.57834  107204124   0.00
# 27       -118.57730  106322549   0.00
# 28       -118.57730  107983686   0.00
# 29       -118.57730  110802913   0.00
# ..              ...        ...    ...
# 367      -118.57479  114106239  11.00
# 368      -118.57477  110088205  11.25
# 369      -118.57477  114067527  11.00
# 370      -118.57477  110088242  12.00
# 371      -118.57572  111711761  12.00
# 372      -118.58564  114104119  12.00
# 373      -118.57477  105908296  12.50
# 374      -118.57120  106132438  13.00
# 375      -118.57479  115681899  13.25
# 376      -118.57634  109630293  13.00
# 377      -118.58542  114104188  13.00
# 378      -118.57588  112499951  13.50
# 379      -118.57588  111726081  14.00
# 380      -118.57949  111686451   5.00
# 381      -118.58630  114054774  -1.00
# 382      -118.57516  107032776  -0.25
# 383      -118.57516  107032780  -0.25
# 384      -118.57534  106322572  -0.25
# 385      -118.57777  107519098  -0.25
# 386      -118.59550  107460413   0.50
# 387      -118.64973  114054613   3.00
# 388      -118.57484  114145837  11.00
# 389      -118.57492  115681926  11.00
# 390      -118.55503  115394196  11.00
# 391      -118.57834  106070952  11.50
# 392      -118.57492  105908186  11.75
# 393      -118.57760  111684005  12.00
# 394      -118.57760  113891171  12.00
# 395      -118.57479  109563866  12.00
# 396      -118.57479  114106367  12.00
#
# [397 rows x 14 columns]

# %%
bishop_proc_df = pd.read_csv("data/processed-csv/bishop-proc-df.csv", index_col = 0) # Imports

# %%
bishop_proc_df
# Out:
#                          Route             ID  Avg Stars  Grade  Length  \
# 0                 The Way Down      106277533        1.3  -1.00    10.0
# 1            Choke the Chicken      116715444        2.0  -1.00    15.0
# 2                   Unnamed  1     1070327761        2.2  -0.25    18.0
# 3                   Unnamed  2     1070327802        2.8  -0.25    18.0
# 4                    Problem B      106322572        1.8  -0.25    12.0
# 5                Hip Hop Hager      107519098        1.6  -0.25    16.0
# 6                Unknown V0/V1    10644277101        1.8  -0.25    12.0
# 7                Xenolith Slab      116715297        2.0  -0.25    10.0
# 8               Backside Crack      108010816        2.3   0.00    20.0
# 9              Burned and Bare      108880968        2.7   0.00    15.0
# 10               Original Line      108054564        3.1   0.00    35.0
# 11                Vic's Demise      111450402        3.0   0.25    35.0
# 12           Essential Peabody      106395083        3.1   0.00    40.0
# 13    Advanced Rockcraft Arete      109526745        3.5   0.25    50.0
# 14                   Problem A      106277503        1.4   0.00    12.0
# 15             Birthday Mantel      106277514        2.5   0.00    12.0
# 16                   Problem B      106277521        2.1   0.00    12.0
# 17                  Unnamed  3     1070327853        2.5   0.00    18.0
# 18                   Problem A      106322566        2.0   0.00    15.0
# 19                 Hager Arete      105936748        2.6   0.00    15.0
# 20               Unnamed Arete      105936754        1.7   0.00    20.0
# 21                      Unnmed      111731481        1.9   0.00    15.0
# 22                   Hero Roof      106094805        3.4   0.00    14.0
# 23                   Tall Edgy      115681932        2.5   0.00    24.0
# 24             Northwest Flake      106322549        2.1   0.00    12.0
# 25          Unnamed Slab/Arete      106130723        2.5   0.00    18.0
# 26                   Problem C      106336055        2.4   0.00    25.0
# 27           Left Facing Arete      114316077        2.5   0.00    12.0
# 28                  Unnamed V0     1064427280        2.4   0.00    20.0
# 29                Yo! Basecamp      114076356        2.3   0.00    10.0
# ...                        ...            ...        ...    ...     ...
# 980          Humpty Dumpty Low      106329071        2.7   7.00    18.0
# 981                    Pinball      106329098        2.0   7.00    20.0
# 982              Lawnmower Man      106340940        3.9   7.00    18.0
# 983                  Los Locos      106340949        4.0   7.00    25.0
# 984   Hauck a Loogie Eliminate      106637379        2.7   7.00    12.0
# 985             Feeding Frenzy      106731632        2.5   7.00    15.0
# 986                 Rad Parrot      106740015        3.0   7.00    20.0
# 987                  Problem B      106915438        2.0   7.00    10.0
# 988                 Slunk Left      114115528        2.5   7.00     9.0
# 989        It's All About Love      106068468        2.8   7.75    10.0
# 990            Mecha-Streisand      106322822        2.0   7.75    10.0
# 991         Water Hazard Right      112289839        2.0   7.75    16.0
# 992                  Mr Frosty      106095536        3.0   7.75     8.0
# 993                  Frostbite      111726377        2.5   8.00    15.0
# 994            Death Star 2000  1066172282000        2.7   8.00    12.0
# 995                    Pow Pow      106068479        3.6   8.00    10.0
# 996                    Honalee      112513100        2.5   8.00    10.0
# 997     Bubba Escapes the Ward      106322788        2.0   9.00    16.0
# 998             The Ninth Wave      106322848        3.2   9.00    20.0
# 999           Enter The Dragon      112513071        3.0   9.00    12.0
# 1000         Aquatic Hitchiker      108730349        3.0   9.75     8.0
# 1001                  Beefcake      106068510        3.2  10.00    14.0
#       OnToDoLists  Ticks
# 0               8     52
# 1               0      1
# 2              11     87
# 3              49    168
# 4              12    102
# 5               2      4
# 6               7     28
# 7               0      1
# 8               5     35
# 9               2      9
# 10             25     23
# 11              6      2
# 12            124     84
# 13             44     11
# 14             14     30
# 15             79    153
# 16             16     38
# 17              6     40
# 18             19     74
# 19             16     43
# 20              3      8
# 21              4     14
# 22            412    722
# 23              1      4
# 24             13     66
# 25             13     17
# 26              5      7
# 27              3      3
# 28             10     92
# 29              3     11
# ...           ...    ...
# 980             0      1
# 981             0      0
# 982            79     12
# 983            44      4
# 984             0      2
# 985             8     17
# 986             0      0
# 987             0      2
# 988             2      2
# 989            10     11
# 990             4      0
# 991             7     14
# 992             3      0
# 993             2      4
# 994             8      1
# 995            77     67
# 996             5      1
# 997             3      0
# 998             7      4
# 999             6      1
# 1000           14     11
# 1001           28     14
# 1002           14     13
# 1003            0      0
# 1004            5      0
# 1005           11      9
# 1006           12      0
# 1007            1      0
# 1008            3      0
# 1009            4      1
#
# [1010 rows x 11 columns]

# %%
# For ordinary-least-squares linear regression
def add_log_values(df):
    df['Log StarRatings'] = df['StarRatings'].apply(lambda x: math.log(x+1, 10))
    df['Log Ticks'] = df['Ticks'].apply(lambda x: math.log(x+1, 10))
    df['Log Avg Stars'] = df['Avg Stars'].apply(lambda x: math.log(x+1, 10))
    df['Log Length'] = df['Length'].apply(lambda x: math.log(x+1, 10))
    df['Log Grade'] = df['Grade'].apply(lambda x: math.log(x+2, 10))
    df['Log OnToDoLists'] = df['OnToDoLists'].apply(lambda x: math.log(x+1, 10)) # Target
    return df

# For Poisson regression
def add_sqrt_values(df):
    df['Sqrt StarRatings'] = df['StarRatings'].apply(lambda x: math.sqrt(x))
    df['Sqrt Ticks'] = df['Ticks'].apply(lambda x: math.sqrt(x))
    df['Sqrt Avg Stars'] = df['Avg Stars'].apply(lambda x: math.sqrt(x))
    df['Sqrt Length'] = df['Length'].apply(lambda x: math.sqrt(x))
    df['Sqrt Grade'] = df['Grade'].apply(lambda x: math.sqrt(x+1)) # Target
    return df

# %%
# Bishop

bishop_proc_df = pd.read_csv(r"data/processed-csv/bishop-proc-df.csv") # Imports
bishop_proc_df = bishop_proc_df.drop(columns = ["Unnamed: 0"]).dropna()
bishop_proc_log_df = add_log_values(bishop_proc_df)
bishop_proc_log_sqrt_df = add_sqrt_values(bishop_proc_log_df)
bishop_proc_df.to_csv(r"data/processed-csv/bishop-proc-log-sqrt-df.csv") # Export

# %%
# Joshua Tree

joshua_tree_proc_df = pd.read_csv(r"data/processed-csv/joshua_tree-proc-df.csv") # Imports
joshua_tree_proc_df = joshua_tree_proc_df.drop(columns = ["Unnamed: 0"]).dropna()
joshua_tree_proc_log_df = add_log_values(joshua_tree_proc_df)
joshua_tree_proc_log_sqrt_df = add_sqrt_values(joshua_tree_proc_log_df)
joshua_tree_proc_df.to_csv(r"data/processed-csv/joshua_tree-proc-log-sqrt-df.csv") # Export
