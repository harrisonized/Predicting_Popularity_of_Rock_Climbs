# %%
import pandas as pd
import math

import pandas.io.sql as pd_sql
import psycopg2 as pg
from sqlalchemy import create_engine

# psychopg connection parameters
params = {'user': 'postgres', 'host': 'localhost', 'port': 5432, 'password': None}
connection = pg.connect(**params, dbname='mountain_project') # Connect
cursor = connection.cursor()

# sqlalchemy connection arguments
connection_str = f'postgres://postgres:{None}@localhost:5432/mountain_project'
engine = create_engine(connection_str)

# %%
buttermilks_scraped_df = pd.read_csv(r"data/scraped-data/buttermilks-scrape.csv")

# %%
buttermilks_scraped_df
# Out:
#                            route  \
# 0                   The Way Down
# 1                      East Face
# 2                      Problem A
# 3              Choke the Chicken
# 4                     Unnamed VB
# 5         Fear of a Black Planet
# 6                     Unnamed VB
# 7                Knobs and Flake
# 8                      Downclimb
# 9                     Unnamed  1
# 10                    Unnamed  2
# 11                     Problem B
# 12                 Hip Hop Hager
# 13                 Unknown V0/V1
# 14                     Problem A
# 15                     Problem C
# 16                 Xenolith Slab
# 17                     Knob Slab
# 18                Backside Crack
# 19               Burned and Bare
# 20                 Original Line
# 21                  Vic's Demise
# 22             Essential Peabody
# 23      Advanced Rockcraft Arete
# 24                     Problem A
# 25               Birthday Mantel
# 26                     Problem B
# ...

# %%
# Bishop, combine the following four files after cleaning

buttermilks_df = pd.read_csv(r"data/downloads/buttermilks.csv")
collect_data(buttermilks_df)
buttermilks_df.to_csv(r"data/scraped-data/buttermilks-df.csv")

druid_stones_df = pd.read_csv(r"data/downloads/druid_stones.csv")
collect_data(druid_stones_df)
druid_stones_df.to_csv(r"data/scraped-data/druid_stones-df.csv")

happy_boulders_df = pd.read_csv(r"data/downloads/happy_boulders.csv")
collect_data(happy_boulders_df)
happy_boulders_df.to_csv(r"data/scraped-data/happy_boulders-df.csv")

sad_boulders_df = pd.read_csv(r"data/downloads/sad_boulders.csv")
collect_data(sad_boulders_df)
sad_boulders_df.to_csv(r"data/scraped-data/sad_boulders-df.csv")

# %%
# Joshua Tree

joshua_tree_df = pd.read_csv(r"data/downloads/joshua_tree.csv")
collect_data(joshua_tree_df)
joshua_tree_df.to_csv(r"data/scraped-data/joshua_tree-df.csv")
